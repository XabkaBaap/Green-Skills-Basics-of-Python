# %%
import pandas as pd

# Defining renewable energy sources
renewable_sources = {"Wind", "Solar", "Geothermal", "Hydropower"}

# Defining the data
data = {
    "Project": ["Solar Farm A", "Wind Turbine X", "Hydropower Y", "Solar Roof Z", "Geothermal Plant P"],
    "Technology": ["Solar", "Wind", "Hydropower", "Solar", "Geothermal"],
    "Capacity (MW)": [150, 300, 200, 50, 100],  # Megawatts
    "Cost (Million $)": [200, 400, 350, 100, 250],  # Project cost
    "Location": ["California", "Texas", "Washington", "Nevada", "Idaho"],
    "Completion Year": [2023, 2024, 2022, 2025, 2023]
}

# Creating the DataFrame
df = pd.DataFrame(data)

# Displaying the DataFrame
print(df)
# Out:
#               Project  Technology  Capacity (MW)  Cost (Million $)  \
# 0        Solar Farm A       Solar            150               200
# 1      Wind Turbine X        Wind            300               400
# 2        Hydropower Y  Hydropower            200               350
# 3        Solar Roof Z       Solar             50               100
# 4  Geothermal Plant P  Geothermal            100               250
#
#      Location  Completion Year
# 0  California             2023
# 1       Texas             2024
# 2  Washington             2022
# 3      Nevada             2025
# 4       Idaho             2023

# %%
grouped_data = projects_df.groupby("Technology")["capacity"].sum()
print("Total capacity by technology\n")
print(grouped_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 grouped_data = projects_df.groupby("Technology")["capacity"].sum()
#       2 print("Total capacity by technology\n")
#       3 print(grouped_data)
#
# NameError: name 'projects_df' is not defined

# %%
import numpy as np
twodarray = np.array(([1,2], [3,4]))
print(twodarray)
# Out:
# [[1 2]
#  [3 4]]

# %%
twodarray.shape
twodarray.ndim
# Out:
# 2

# %%
 np.ones(3)
# Out:
# array([1., 1., 1.])

# %%
np.zeros(3)
# Out:
# array([0., 0., 0.])

# %%
array1 = np.arange(0,10,2)
print(array1)

array2 = np.arange(5,15,2)
print(array2)
# Out:
# [0 2 4 6 8]
# [ 5  7  9 11 13]

# %%
linspace_array1 = np.linspace(5,10,3)
print(linspace_array1)
# Out:
# [ 5.   7.5 10. ]

# %%
num_data = np.array([[1, 2, 3], [4, 5, 6]])
reshaped_data = num_data.reshape(2, 3)
print(reshaped_data)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
import pandas as pd
data = {
    "Energy Source": ["Solar", "Wind", "Hydropower", "Geothermal", "Biomass", "Nuclear"],
    "Energy Consumption (MWh)": [1200, np.nan, 2900, np.nan, 2500, 3200],
    "Cost (Million $)": [200, 400, np.nan, 150, 250, np.nan]
}

energy_df = pd.DataFrame(data)
print(energy_df)
# Out:
#   Cell In[34], line 5
#     "Cost (Million $)": [200, 400, np.nan, 150, 250, np.nan]
#                                                ^
# SyntaxError: invalid non-printable character U+00A0

# %%
forward_filled_df = energy_df.fillna(method="ffill")
print("\nData before Forward Filling:\n")
print(energy_df)
print("Data after Forward Filling:\n")
forward_filled_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 forward_filled_df = energy_df.fillna(method="ffill")
#       2 print("\nData before Forward Filling:\n")
#       3 print(energy_df)
#
# NameError: name 'energy_df' is not defined

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
energy_df[["Energy Consumption (MWh)", "Cost (Million $)"]] = scalar.fit_transform(energy_df[["Energy Consumption (MWh)", "Cost (Million $)"]])
print("Data after normalozation\n")
print(energy_df)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 from sklearn.preprocessing import MinMaxScaler
#       2 scaler = MinMaxScaler()
#       3 energy_df[["Energy Consumption (MWh)", "Cost (Million $)"]] = scalar.fit_transform(energy_df[["Energy Consumption (MWh)", "Cost (Million $)"]])
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
energy_encoded_df = pd.get_dummies(energy_df,columns=["Energy Source"])
print("Data after one-hot encoding")
energy_encoded_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 energy_encoded_df = pd.get_dummies(energy_df,columns=["Energy Source"])
#       2 print("Data after one-hot encoding")
#       3 energy_encoded_df.head()
#
# NameError: name 'energy_df' is not defined

# %%
import matplotlib.pyplot as plt

#Sample data for energy consumption over 6 months (in Mich)
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun']
energy_consumption= [1200, 1300, 1100, 1500, 1400, 1600]


#Create a Line plot
plt.plot(months, energy_consumption, marker='o', color='b', linestyle='--')

#Add titles and Labels
plt.title('Energy Consumption Over 6 Months')
plt.xlabel('Month')
plt.ylabel('Energy Consumption (MWh)')
plt.show()

# %%
plt.pie(energy_consumption, labels=energy_consumption, autopct='%1.1f%%', startangle=90)

plt.title('Energy Consumption by Source')

plt.show()

# %%
# Sample data for energy consumption and carbon emissions

carbon_emissions = [200, 500, 450, 300,500,600] # in kg CO2

#Create a scatter plot

plt.scatter(energy_consumption, carbon_emissions, color='red')

#Add titles and Labels

plt.title('Energy Consumption vs Carbon Emissions')

plt.xlabel('Energy Consumption (MWh)')

plt.ylabel('Carbon Emissions (kg CO2)')

plt.show()

# %%
import numpy as np

import matplotlib.pyplot as plt

#Y-axis values

y1= [2, 3, 4.5]

#Y-axis values

y2= [1, 1.5, 5]

#Function to plot

plt.plot(y1)

plt.plot(y2)

#Function add a Legend

plt.legend(["blue", "green"], loc ="lower right")

#function to show the plot

plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

#Creating a DataFrame for pair plot
data = {
"Solar": [1200, 1500, 1300],
"Wind": [3400, 3600, 3200],
"Hydropower": [2900, 3100, 2800],
"Blomass": [2500, 2700, 2400]
}

df =pd.DataFrame(data)
#a Ceate a pair plot 
sns.pairplot(df)
plt.show()

# %%
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.show('Correaltion Between Energy Sources')
plt.show()

# %%
sns.boxplot(data=df)
plt.title("Distribution of Energy Consumption by Source")
plt.show()

# %%
sns.violinplot(data=df)
plt.title("Violin Plot of Energy Consumption Distribution")
plt.show()

# %%
energy_values = [100,200,300,400,500]
carbon_emissions = [10,20,25,40,50]

df_reg = pd.DataFrame({
    "Energy Consumption" : energy_values,
    "Carbon Emissions" : carbon_emissions
})
sns.regplot(x="Energy Consumption", y = "Carbon Emissions", data=df_reg)

plt.title("")
plt.show()

# %%
from mpl_toolkits import mplot3d
import numpy as np
fig=plt.figure()
ax=plt.axes(projection='3d')
z = np.linspace(0,1,1000)
x=z*np.sin(25*z)
y=z*np.cos(25*z)
ax.plot3D(x,y,z,'green')
ax.set_title('3D line plot')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv("C:/Users/rugwe/Downloads/IRIS.csv") 

# 1. Pair Plot
sns.pairplot(df)
plt.title('Pair Plot')
plt.show()

# %%
sns.boxplot(data=df)
plt.title('Box Plot')
plt.show()

# %%
sns.violinplot(data=df)
plt.title('Violin Plot')
plt.show()

# %%
sns.pairplot(df,hue = 'species', palette="husl", size=2)
plt.show()
# Out:
# C:\Users\rugwe\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\axisgrid.py:2100: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
import numpy as np
numerical_data = df.select_dtypes(include=[np.number])

# Calculate the correlation matrix
corr_matrix = numerical_data.corr()

sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Heatmap of Correlations')
plt.show()
